# %% [markdown]
# # Load libraries

# %%
import os
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Images & OpenCV

# %%
train_image_files_path = "/keras2production/fruits/Training/"
valid_image_files_path = "/keras2production/fruits/Test/"

# %%
## within jupyter it is possible to execute command line code and assign it to python object
## following line makes shure that there is no .DS_Store included -- due to the mac file system
beispiel_bilder = !find $train_image_files_path -type f -name "*.jpg"

# %%
num_beispiel_bilder = 24
beispiel_bilder = random.sample(beispiel_bilder, num_beispiel_bilder)

fig = plt.figure(figsize=(12,8))

kernel = np.ones((5,5),np.float32)/25

for i in range(num_beispiel_bilder):
    fig.add_subplot(4, 6, i + 1)
    plt.axis('off')
    img = plt.imread(beispiel_bilder[i])
#    img = cv2.imread(beispiel_bilder[i], 1)
#    img = cv2.filter2D(img,-1,kernel)
    plt.imshow(img)

# %%
img = cv2.imread(beispiel_bilder[1])
plt.imshow(img)
